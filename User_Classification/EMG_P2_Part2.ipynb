# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
i=1
data = pd.read_csv('/content/gdrive/MyDrive/EMG/Sessions/Session{}.csv'.format(i))

X = data.iloc[0:,3:]
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X)
y = data.iloc[0:,0]
sequence_length = 33
batch_size = 33
X_batches = []
y_batches = []

for i in range(0, len(X) - sequence_length + 1, batch_size):
  X_batch = X.iloc[i:i+sequence_length]
  y_batch = y.iloc[i]

  X_batches.append(X_batch)
  y_batches.append(y_batch)

from keras.utils import to_categorical
y_batches = np.array(y_batches) - 1
y_batches = to_categorical(y_batches)
X_batches = np.array(X_batches)

X_train, X_test, y_train, y_test = train_test_split(X_batches, y_batches, test_size=0.3, random_state = 42)

model = Sequential()
model.add(LSTM(128, input_shape=(33, 168),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(43, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

history1 = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

predicted_classes = np.argmax(model.predict(X_test), axis=-1)
true_classes = np.argmax(y_test, axis=-1)
accuracy = accuracy_score(true_classes, predicted_classes)
print(f'Accuracy: {accuracy*100:.2f}%')
report = classification_report(true_classes, predicted_classes)
print(report)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 33, 128)           152064
#
#  dropout (Dropout)           (None, 33, 128)           0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 43)                2795
#
# =================================================================
# Total params: 204267 (797.92 KB)
# Trainable params: 204267 (797.92 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 112/112 [==============================] - 11s 18ms/step - loss: 3.1079 - accuracy: 0.2706 - val_loss: 2.5401 - val_accuracy: 0.4284
# Epoch 2/100
# 112/112 [==============================] - 1s 9ms/step - loss: 2.0072 - accuracy: 0.5359 - val_loss: 1.7310 - val_accuracy: 0.5866
# Epoch 3/100
# 112/112 [==============================] - 1s 9ms/step - loss: 1.4310 - accuracy: 0.6521 - val_loss: 1.4298 - val_accuracy: 0.6439
# Epoch 4/100
# 112/112 [==============================] - 1s 9ms/step - loss: 1.2062 - accuracy: 0.7048 - val_loss: 1.1594 - val_accuracy: 0.7012
# Epoch 5/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.9207 - accuracy: 0.7822 - val_loss: 0.9761 - val_accuracy: 0.7487
# Epoch 6/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.7324 - accuracy: 0.8260 - val_loss: 0.7952 - val_accuracy: 0.8040
# Epoch 7/100
# 112/112 [==============================] - 2s 13ms/step - loss: 0.6728 - accuracy: 0.8352 - val_loss: 0.8328 - val_accuracy: 0.7917
# Epoch 8/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.5808 - accuracy: 0.8551 - val_loss: 0.7432 - val_accuracy: 0.8145
# Epoch 9/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.5247 - accuracy: 0.8755 - val_loss: 0.6055 - val_accuracy: 0.8464
# Epoch 10/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4178 - accuracy: 0.9039 - val_loss: 0.6498 - val_accuracy: 0.8229
# Epoch 11/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.4207 - accuracy: 0.8972 - val_loss: 0.6385 - val_accuracy: 0.8301
# Epoch 12/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.4180 - accuracy: 0.8972 - val_loss: 0.4973 - val_accuracy: 0.8665
# Epoch 13/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3572 - accuracy: 0.9148 - val_loss: 0.5080 - val_accuracy: 0.8633
# Epoch 14/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3652 - accuracy: 0.9129 - val_loss: 0.4554 - val_accuracy: 0.8802
# Epoch 15/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3474 - accuracy: 0.9145 - val_loss: 0.4730 - val_accuracy: 0.8704
# Epoch 16/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0972 - accuracy: 0.9732 - val_loss: 0.2791 - val_accuracy: 0.9336
# Epoch 78/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0935 - accuracy: 0.9751 - val_loss: 0.2545 - val_accuracy: 0.9342
# Epoch 79/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1124 - accuracy: 0.9682 - val_loss: 0.3524 - val_accuracy: 0.9102
# Epoch 80/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1526 - accuracy: 0.9587 - val_loss: 0.4360 - val_accuracy: 0.8822
# Epoch 81/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1340 - accuracy: 0.9626 - val_loss: 0.3269 - val_accuracy: 0.9154
# Epoch 82/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1251 - accuracy: 0.9654 - val_loss: 0.3267 - val_accuracy: 0.9199
# Epoch 83/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0922 - accuracy: 0.9751 - val_loss: 0.2770 - val_accuracy: 0.9258
# Epoch 84/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0601 - accuracy: 0.9849 - val_loss: 0.3446 - val_accuracy: 0.9115
# Epoch 85/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0668 - accuracy: 0.9805 - val_loss: 0.3543 - val_accuracy: 0.9102
# Epoch 86/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0728 - accuracy: 0.9779 - val_loss: 0.2654 - val_accuracy: 0.9310
# Epoch 87/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1018 - accuracy: 0.9698 - val_loss: 0.3753 - val_accuracy: 0.8997
# Epoch 88/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1560 - accuracy: 0.9573 - val_loss: 0.3044 - val_accuracy: 0.9316
# Epoch 89/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0960 - accuracy: 0.9738 - val_loss: 0.3473 - val_accuracy: 0.9141
# Epoch 90/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.1363 - accuracy: 0.9631 - val_loss: 0.2947 - val_accuracy: 0.9271
# Epoch 91/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1010 - accuracy: 0.9729 - val_loss: 0.2631 - val_accuracy: 0.9368
# Epoch 92/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0473 - accuracy: 0.9869 - val_loss: 0.2400 - val_accuracy: 0.9395
# Epoch 93/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0492 - accuracy: 0.9866 - val_loss: 0.2361 - val_accuracy: 0.9395
# Epoch 94/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0536 - accuracy: 0.9855 - val_loss: 0.2227 - val_accuracy: 0.9453
# Epoch 95/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0369 - accuracy: 0.9902 - val_loss: 0.2071 - val_accuracy: 0.9499
# Epoch 96/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0433 - accuracy: 0.9897 - val_loss: 0.2007 - val_accuracy: 0.9479
# Epoch 97/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0925 - accuracy: 0.9732 - val_loss: 0.3746 - val_accuracy: 0.9121
# Epoch 98/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1251 - accuracy: 0.9657 - val_loss: 0.3291 - val_accuracy: 0.9147
# Epoch 99/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1446 - accuracy: 0.9612 - val_loss: 0.3518 - val_accuracy: 0.9069
# Epoch 100/100
# 112/112 [==============================] - 2s 19ms/step - loss: 0.1446 - accuracy: 0.9623 - val_loss: 0.4412 - val_accuracy: 0.8919
# 48/48 [==============================] - 4s 10ms/step
# Accuracy: 89.19%
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        39
#            1       0.96      0.98      0.97        45
#            2       1.00      0.87      0.93        39
#            3       0.90      0.75      0.82        36
#            4       0.94      0.87      0.90        38
#            5       0.81      0.95      0.88        41
#            6       0.86      0.93      0.89        40
#            7       0.97      0.90      0.93        31
#            8       0.73      0.97      0.84        34
#            9       0.78      0.79      0.78        39
#           10       0.89      0.80      0.84        30
#           11       0.86      0.97      0.91        32
#           12       0.91      0.79      0.85        38
#           13       0.97      1.00      0.99        35
#           14       0.92      0.80      0.85        44
#           15       0.97      0.97      0.97        37
#           16       1.00      0.83      0.91        30
#           17       0.76      0.94      0.84        34
#           18       0.88      0.95      0.91        39
#           19       0.92      0.92      0.92        37
#           20       0.91      0.87      0.89        23
#           21       0.90      0.87      0.89        31
#           22       0.78      0.97      0.86        29
#           23       1.00      0.83      0.91        30
#           24       0.97      0.97      0.97        31
#           25       0.97      0.89      0.93        36
#           26       0.87      0.89      0.88        44
#           27       0.97      0.88      0.92        32
#           28       0.86      0.89      0.87        35
#           29       0.80      0.93      0.86        30
#           30       0.97      0.95      0.96        38
#           31       0.94      0.94      0.94        31
#           32       0.93      0.76      0.83        49
#           33       0.91      0.91      0.91        34
#           34       0.91      0.85      0.88        34
#           35       0.89      0.74      0.81        34
#           36       0.91      0.98      0.95        44
#           37       0.79      0.94      0.86        33
#           38       1.00      0.90      0.95        40
#           39       0.88      0.85      0.87        34
#           40       0.86      0.84      0.85        37
#           41       0.66      1.00      0.79        31
#           42       1.00      0.84      0.91        38
#
#     accuracy                           0.89      1536
#    macro avg       0.90      0.89      0.89      1536
# weighted avg       0.90      0.89      0.89      1536

# %%
i=2
data = pd.read_csv('/content/gdrive/MyDrive/EMG/Sessions/Session{}.csv'.format(i))

X = data.iloc[0:,3:]
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X)
y = data.iloc[0:,0]
sequence_length = 33
batch_size = 33
X_batches = []
y_batches = []

for i in range(0, len(X) - sequence_length + 1, batch_size):
  X_batch = X.iloc[i:i+sequence_length]
  y_batch = y.iloc[i]

  X_batches.append(X_batch)
  y_batches.append(y_batch)

from keras.utils import to_categorical
y_batches = np.array(y_batches) - 1
y_batches = to_categorical(y_batches)
X_batches = np.array(X_batches)

X_train, X_test, y_train, y_test = train_test_split(X_batches, y_batches, test_size=0.3, random_state = 42)

model = Sequential()
model.add(LSTM(128, input_shape=(33, 168),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(43, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

history2 = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

predicted_classes = np.argmax(model.predict(X_test), axis=-1)
true_classes = np.argmax(y_test, axis=-1)
accuracy = accuracy_score(true_classes, predicted_classes)
print(f'Accuracy: {accuracy*100:.2f}%')
report = classification_report(true_classes, predicted_classes)
print(report)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 33, 128)           152064
#
#  dropout_2 (Dropout)         (None, 33, 128)           0
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 204267 (797.92 KB)
# Trainable params: 204267 (797.92 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 112/112 [==============================] - 15s 32ms/step - loss: 3.0816 - accuracy: 0.2756 - val_loss: 2.4780 - val_accuracy: 0.4466
# Epoch 2/100
# 112/112 [==============================] - 2s 18ms/step - loss: 2.0058 - accuracy: 0.5364 - val_loss: 1.7182 - val_accuracy: 0.5924
# Epoch 3/100
# 112/112 [==============================] - 2s 17ms/step - loss: 1.4859 - accuracy: 0.6375 - val_loss: 1.4569 - val_accuracy: 0.6530
# Epoch 4/100
# 112/112 [==============================] - 2s 17ms/step - loss: 1.1418 - accuracy: 0.7258 - val_loss: 1.2407 - val_accuracy: 0.6908
# Epoch 5/100
# 112/112 [==============================] - 2s 19ms/step - loss: 0.8467 - accuracy: 0.7989 - val_loss: 0.9157 - val_accuracy: 0.7734
100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0683 - accuracy: 0.9810 - val_loss: 0.3310 - val_accuracy: 0.9277
# Epoch 90/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0698 - accuracy: 0.9793 - val_loss: 0.2963 - val_accuracy: 0.9232
# Epoch 91/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0745 - accuracy: 0.9771 - val_loss: 0.3888 - val_accuracy: 0.9141
# Epoch 92/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0987 - accuracy: 0.9729 - val_loss: 0.3318 - val_accuracy: 0.9199
# Epoch 93/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0822 - accuracy: 0.9771 - val_loss: 0.2834 - val_accuracy: 0.9290
# Epoch 94/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0731 - accuracy: 0.9796 - val_loss: 0.3096 - val_accuracy: 0.9212
# Epoch 95/100
# 112/112 [==============================] - 2s 18ms/step - loss: 0.0611 - accuracy: 0.9818 - val_loss: 0.2627 - val_accuracy: 0.9375
# Epoch 96/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0344 - accuracy: 0.9905 - val_loss: 0.2448 - val_accuracy: 0.9453
# Epoch 97/100
# 112/112 [==============================] - 2s 18ms/step - loss: 0.0628 - accuracy: 0.9824 - val_loss: 0.2861 - val_accuracy: 0.9290
# Epoch 98/100
# 112/112 [==============================] - 3s 24ms/step - loss: 0.0601 - accuracy: 0.9827 - val_loss: 0.2357 - val_accuracy: 0.9486
# Epoch 99/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0603 - accuracy: 0.9830 - val_loss: 0.4019 - val_accuracy: 0.9069
# Epoch 100/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.1294 - accuracy: 0.9626 - val_loss: 0.3462 - val_accuracy: 0.9108
# 48/48 [==============================] - 1s 5ms/step
# Accuracy: 91.08%
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90        39
#            1       0.89      0.91      0.90        45
#            2       0.95      0.90      0.92        39
#            3       0.83      0.94      0.88        36
#            4       1.00      0.92      0.96        38
#            5       0.95      0.93      0.94        41
#            6       0.83      0.88      0.85        40
#            7       0.89      1.00      0.94        31
#            8       0.89      1.00      0.94        34
#            9       0.84      0.92      0.88        39
#           10       0.81      0.97      0.88        30
#           11       0.90      0.81      0.85        32
#           12       1.00      0.74      0.85        38
#           13       1.00      0.97      0.99        35
#           14       0.97      0.80      0.88        44
#           15       0.86      1.00      0.92        37
#           16       0.94      1.00      0.97        30
#           17       0.97      0.97      0.97        34
#           18       0.94      0.82      0.88        39
#           19       0.88      0.95      0.91        37
#           20       0.85      1.00      0.92        23
#           21       0.94      0.97      0.95        31
#           22       0.93      0.93      0.93        29
#           23       0.96      0.87      0.91        30
#           24       0.97      0.94      0.95        31
#           25       0.91      0.89      0.90        36
#           26       1.00      0.95      0.98        44
#           27       0.79      0.97      0.87        32
#           28       1.00      0.91      0.96        35
#           29       1.00      0.97      0.98        30
#           30       1.00      0.97      0.99        38
#           31       0.81      0.94      0.87        31
#           32       0.88      0.94      0.91        49
#           33       0.97      0.97      0.97        34
#           34       0.76      0.91      0.83        34
#           35       0.88      0.82      0.85        34
#           36       0.93      0.93      0.93        44
#           37       0.92      0.67      0.77        33
#           38       0.80      0.82      0.81        40
#           39       0.97      0.94      0.96        34
#           40       0.92      0.89      0.90        37
#           41       0.93      0.90      0.92        31
#           42       0.92      0.89      0.91        38
#
#     accuracy                           0.91      1536
#    macro avg       0.91      0.91      0.91      1536
# weighted avg       0.92      0.91      0.91      1536

# %%
i=3
data = pd.read_csv('/content/gdrive/MyDrive/EMG/Sessions/Session{}.csv'.format(i))

X = data.iloc[0:,3:]
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X)
y = data.iloc[0:,0]
sequence_length = 33
batch_size = 33
X_batches = []
y_batches = []

for i in range(0, len(X) - sequence_length + 1, batch_size):
  X_batch = X.iloc[i:i+sequence_length]
  y_batch = y.iloc[i]

  X_batches.append(X_batch)
  y_batches.append(y_batch)

from keras.utils import to_categorical
y_batches = np.array(y_batches) - 1
y_batches = to_categorical(y_batches)
X_batches = np.array(X_batches)

X_train, X_test, y_train, y_test = train_test_split(X_batches, y_batches, test_size=0.3, random_state = 42)

model = Sequential()
model.add(LSTM(128, input_shape=(33, 168),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(43, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

history3 = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

predicted_classes = np.argmax(model.predict(X_test), axis=-1)
true_classes = np.argmax(y_test, axis=-1)
accuracy = accuracy_score(true_classes, predicted_classes)
print(f'Accuracy: {accuracy*100:.2f}%')
report = classification_report(true_classes, predicted_classes)
print(report)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 33, 128)           152064
#
#  dropout_4 (Dropout)         (None, 33, 128)           0
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 204267 (797.92 KB)
# Trainable params: 204267 (797.92 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 112/112 [==============================] - 7s 22ms/step - loss: 3.0882 - accuracy: 0.2748 - val_loss: 2.4314 - val_accuracy: 0.4733
# Epoch 2/100
# 112/112 [==============================] - 1s 11ms/step - loss: 1.9953 - accuracy: 0.5406 - val_loss: 1.7678 - val_accuracy: 0.5846
# Epoch 3/100
# 112/112 [==============================] - 1s 11ms/step - loss: 1.4704 - accuracy: 0.6495 - val_loss: 1.3155 - val_accuracy: 0.6810
# Epoch 4/100
# 112/112 [==============================] - 1s 11ms/step - loss: 1.1996 - accuracy: 0.7079 - val_loss: 1.2024 - val_accuracy: 0.6986
# Epoch 5/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.9418 - accuracy: 0.7758 - val_loss: 0.9639 - val_accuracy: 0.7546
# Epoch 6/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.7851 - accuracy: 0.8129 - val_loss: 0.8187 - val_accuracy: 0.7871
# Epoch 7/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.6954 - accuracy: 0.8308 - val_loss: 0.7930 - val_accuracy: 0.7904
# Epoch 8/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.5774 - accuracy: 0.8626 - val_loss: 0.7104 - val_accuracy: 0.8132
# Epoch 9/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4933 - accuracy: 0.8836 - val_loss: 0.7376 - val_accuracy: 0.8118
# Epoch 10/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.4533 - accuracy: 0.8919 - val_loss: 0.5530 - val_accuracy: 0.8503
# Epoch 11/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.3776 - accuracy: 0.9098 - val_loss: 0.4903 - val_accuracy: 0.8711
# Epoch 12/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.3386 - accuracy: 0.9193 - val_loss: 0.5512 - val_accuracy: 0.8457
# Epoch 13/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.3298 - accuracy: 0.9243 - val_loss: 0.5905 - val_accuracy: 0.8411
# Epoch 14/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.3536 - accuracy: 0.9112 - val_loss: 0.4952 - val_accuracy: 0.8678
# Epoch 15/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3171 - accuracy: 0.9215 - val_loss: 0.4561 - val_accuracy: 0.8704
# Epoch 16/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.3002 - accuracy: 0.9266 - val_loss: 0.4851 - val_accuracy: 0.8776
# Epoch 17/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.
100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1262 - accuracy: 0.9676 - val_loss: 0.4311 - val_accuracy: 0.8932
# Epoch 47/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.2182 - accuracy: 0.9422 - val_loss: 0.3772 - val_accuracy: 0.8932
# Epoch 48/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.1491 - accuracy: 0.9567 - val_loss: 0.3067 - val_accuracy: 0.9154
# Epoch 49/100
# 112/112 [==============================] - 2s 19ms/step - loss: 0.1241 - accuracy: 0.9654 - val_loss: 0.3701 - val_accuracy: 0.9069
# Epoch 50/100
# 112/112 [==============================] - 2s 18ms/step - loss: 0.1497 - accuracy: 0.9567 - val_loss: 0.4142 - val_accuracy: 0.8880
# Epoch 51/100
# 112/112 [==============================] - 2s 20ms/step - loss: 0.1593 - accuracy: 0.9531 - val_loss: 0.3216 - val_accuracy: 0.9160
# Epoch 52/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.1084 - accuracy: 0.9687 - val_loss: 0.3193 - val_accuracy: 0.9264
# Epoch 53/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.1639 - accuracy: 0.9553 - val_loss: 0.4398 - val_accuracy: 0.8789
# Epoch 54/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1767 - accuracy: 0.9472 - val_loss: 0.3779 - val_accuracy: 0.8971
# Epoch 55/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2392 - accuracy: 0.9333 - val_loss: 0.4889 - val_accuracy: 0.8802
# Epoch 56/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.2235 - accuracy: 0.9366 - val_loss: 0.3462 - val_accuracy: 0.9023
# Epoch 57/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1341 - accuracy: 0.9631 - val_loss: 0.3001 - val_accuracy: 0.9206
# Epoch 58/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0818 - accuracy: 0.9788 - val_loss: 0.2523 - val_accuracy: 0.9277
# Epoch 59/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0830 - accuracy: 0.9777 - val_loss: 0.2741 - val_accuracy: 0.9303
# Epoch 60/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0808 - accuracy: 0.9771 - val_loss: 0.2989 - val_accuracy: 0.9277
# Epoch 61/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1059 - accuracy: 0.9726 - val_loss: 0.3677 - val_accuracy: 0.9115
# Epoch 62/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.1202 - accuracy: 0.9640 - val_loss: 0.3399 - val_accuracy: 0.9154
# Epoch 63/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.1096 - accuracy: 0.9687 - val_loss: 0.3248 - val_accuracy: 0.9141
# Epoch 64/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0999 - accuracy: 0.9726 - val_loss: 0.2951 - val_accuracy: 0.9141
# Epoch 65/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1118 - accuracy: 0.9693 - val_loss: 0.3365 - val_accuracy: 0.9049
# Epoch 66/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0940 - accuracy: 0.9707 - val_loss: 0.3064 - val_accuracy: 0.9121
# Epoch 67/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0997 - accuracy: 0.9712 - val_loss: 0.3412 - val_accuracy: 0.9108
# Epoch 68/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1795 - accuracy: 0.9467 - val_loss: 0.5079 - val_accuracy: 0.8607
# Epoch 69/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1492 - accuracy: 0.9576 - val_loss: 0.3643 - val_accuracy: 0.8991
# Epoch 70/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1061 - accuracy: 0.9690 - val_loss: 0.3637 - val_accuracy: 0.9023
# Epoch 71/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1124 - accuracy: 0.9643 - val_loss: 0.3207 - val_accuracy: 0.9102
# Epoch 72/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1060 - accuracy: 0.9701 - val_loss: 0.3587 - val_accuracy: 0.9030
# Epoch 73/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1451 - accuracy: 0.9609 - val_loss: 0.3083 - val_accuracy: 0.9225
# Epoch 74/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1269 - accuracy: 0.9648 - val_loss: 0.3807 - val_accuracy: 0.9010
# Epoch 75/100
# 112/112 [==============================] - 2s 13ms/step - loss: 0.1491 - accuracy: 0.9581 - val_loss: 0.3578 - val_accuracy: 0.9036
# Epoch 76/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0863 - accuracy: 0.9751 - val_loss: 0.3141 - val_accuracy: 0.9212
# Epoch 77/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0655 - accuracy: 0.9810 - val_loss: 0.2573 - val_accuracy: 0.9258
# Epoch 78/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0601 - accuracy: 0.9821 - val_loss: 0.2593 - val_accuracy: 0.9368
# Epoch 79/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.3956 - val_accuracy: 0.9043
# Epoch 80/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0995 - accuracy: 0.9712 - val_loss: 0.2900 - val_accuracy: 0.9245
# Epoch 81/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0670 - accuracy: 0.9821 - val_loss: 0.3353 - val_accuracy: 0.9115
# Epoch 82/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.0845 - accuracy: 0.9751 - val_loss: 0.3455 - val_accuracy: 0.9141
# Epoch 83/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.1398 - accuracy: 0.9640 - val_loss: 0.5239 - val_accuracy: 0.8659
# Epoch 84/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1569 - accuracy: 0.9564 - val_loss: 0.4241 - val_accuracy: 0.8919
# Epoch 85/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1096 - accuracy: 0.9729 - val_loss: 0.3464 - val_accuracy: 0.9095
# Epoch 86/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1097 - accuracy: 0.9682 - val_loss: 0.2760 - val_accuracy: 0.9238
# Epoch 87/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.0845 - accuracy: 0.9735 - val_loss: 0.2704 - val_accuracy: 0.9355
# Epoch 88/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0640 - accuracy: 0.9827 - val_loss: 0.3050 - val_accuracy: 0.9225
# Epoch 89/100
# 112/112 [==============================] - 1s 13ms/step - loss: 0.0861 - accuracy: 0.9757 - val_loss: 0.3276 - val_accuracy: 0.9193
# Epoch 90/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.1044 - accuracy: 0.9679 - val_loss: 0.3559 - val_accuracy: 0.9108
# Epoch 91/100
# 112/112 [==============================] - 1s 12ms/step - loss: 0.1009 - accuracy: 0.9673 - val_loss: 0.2931 - val_accuracy: 0.9238
# Epoch 92/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0822 - accuracy: 0.9726 - val_loss: 0.3779 - val_accuracy: 0.9036
# Epoch 93/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0773 - accuracy: 0.9782 - val_loss: 0.2770 - val_accuracy: 0.9323
# Epoch 94/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0783 - accuracy: 0.9782 - val_loss: 0.3491 - val_accuracy: 0.9108
# Epoch 95/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0591 - accuracy: 0.9827 - val_loss: 0.2815 - val_accuracy: 0.9277
# Epoch 96/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 0.3200 - val_accuracy: 0.9186
# Epoch 97/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0775 - accuracy: 0.9751 - val_loss: 0.3146 - val_accuracy: 0.9277
# Epoch 98/100
# 112/112 [==============================] - 1s 10ms/step - loss: 0.0905 - accuracy: 0.9746 - val_loss: 0.3732 - val_accuracy: 0.9108
# Epoch 99/100
# 112/112 [==============================] - 1s 9ms/step - loss: 0.0812 - accuracy: 0.9765 - val_loss: 0.3595 - val_accuracy: 0.8997
# Epoch 100/100
# 112/112 [==============================] - 1s 11ms/step - loss: 0.1691 - accuracy: 0.9573 - val_loss: 0.4159 - val_accuracy: 0.8997
# 48/48 [==============================] - 1s 4ms/step
# Accuracy: 89.97%
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        39
#            1       0.94      1.00      0.97        45
#            2       1.00      0.62      0.76        39
#            3       0.92      0.97      0.95        36
#            4       0.94      0.87      0.90        38
#            5       0.95      0.93      0.94        41
#            6       0.85      0.88      0.86        40
#            7       0.74      0.94      0.83        31
#            8       0.97      0.88      0.92        34
#            9       0.97      0.85      0.90        39
#           10       0.97      0.97      0.97        30
#           11       0.91      0.97      0.94        32
#           12       0.97      0.87      0.92        38
#           13       0.89      0.91      0.90        35
#           14       0.89      0.75      0.81        44
#           15       0.97      0.95      0.96        37
#           16       0.97      0.93      0.95        30
#           17       0.92      1.00      0.96        34
#           18       0.95      0.92      0.94        39
#           19       0.97      0.92      0.94        37
#           20       0.96      1.00      0.98        23
#           21       0.94      0.94      0.94        31
#           22       0.84      0.93      0.89        29
#           23       0.96      0.90      0.93        30
#           24       0.83      0.97      0.90        31
#           25       0.67      0.97      0.80        36
#           26       0.92      0.82      0.87        44
#           27       0.74      1.00      0.85        32
#           28       1.00      0.91      0.96        35
#           29       0.81      0.97      0.88        30
#           30       0.93      0.97      0.95        38
#           31       0.81      0.97      0.88        31
#           32       0.97      0.80      0.88        49
#           33       0.68      1.00      0.81        34
#           34       0.94      0.94      0.94        34
#           35       0.94      0.85      0.89        34
#           36       0.93      0.95      0.94        44
#           37       0.97      0.85      0.90        33
#           38       0.96      0.65      0.78        40
#           39       0.96      0.76      0.85        34
#           40       0.77      0.97      0.86        37
#           41       0.93      0.84      0.88        31
#           42       0.97      0.84      0.90        38
#
#     accuracy                           0.90      1536
#    macro avg       0.91      0.90      0.90      1536
# weighted avg       0.91      0.90      0.90      1536

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def plot_loss_and_accuracy(history, session_name):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{session_name} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper right')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{session_name} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='lower right')

    plt.show()


def plot_confusion_matrix(model, X_test, y_test, session_name):
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    true_classes = np.argmax(y_test, axis=1)

    cm = confusion_matrix(true_classes, y_pred_labels)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(43), yticklabels=range(43))
    plt.title(f'{session_name} Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
plot_loss_and_accuracy(history1, 'Session 1')

# %%
plot_confusion_matrix(model, X_test, y_test, 'Session 1')
# Out:
# 48/48 [==============================] - 0s 5ms/step

# %%
plot_loss_and_accuracy(history2, 'Session 2')

# %%
plot_confusion_matrix(model, X_test, y_test, 'Session 2')
# Out:
# 48/48 [==============================] - 0s 8ms/step

# %%
plot_loss_and_accuracy(history3, 'Session 3')

# %%
plot_confusion_matrix(model, X_test, y_test, 'Session 3')
# Out:
# 48/48 [==============================] - 0s 6ms/step

# %%
import pickle
with open('/content/gdrive/MyDrive/EMG/Sessions/training_history1.pkl', 'wb') as file:
    pickle.dump(history1.history, file)

# %%
with open('/content/gdrive/MyDrive/EMG/Sessions/training_history2.pkl', 'wb') as file:
    pickle.dump(history2.history, file)

# %%
with open('/content/gdrive/MyDrive/EMG/Sessions/training_history3.pkl', 'wb') as file:
    pickle.dump(history3.history, file)
